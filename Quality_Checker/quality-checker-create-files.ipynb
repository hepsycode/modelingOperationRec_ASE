# %%
import os
from pytextdist.preprocessing import phrase_preprocessing

# %%
# Diversity Metrics
import os
from pytextdist.preprocessing import phrase_preprocessing
from pytextdist.edit_distance import levenshtein_distance, levenshtein_similarity
from pytextdist.edit_distance import lcs_distance, lcs_similarity
from pytextdist.edit_distance import damerau_levenshtein_distance, damerau_levenshtein_similarity
from pytextdist.edit_distance import hamming_distance, hamming_similarity
from pytextdist.edit_distance import jaro_similarity, jaro_winkler_similarity
from pytextdist.vector_similarity import cosine_similarity
from pytextdist.vector_similarity import jaccard_similarity
from pytextdist.vector_similarity import sorensen_dice_similarity
from pytextdist.vector_similarity import qgram_similarity
import pandas as pd
import textdistance

pathReal = str(os.getcwd()) + '\XES-MORGAN' + '\\'
pathGemini = str(os.getcwd()) + '\XES-MORGAN-LLM-GPT4' + '\\'
print(pathReal)

data = []
for rootReal, dirsReal, filesReal in os.walk(pathReal):
    for fileReal in filesReal:
        if fileReal.endswith(".xes"):
            pathfileReal = pathReal + fileReal
            print(pathfileReal)
            file1Real = open(pathfileReal, 'r')
            LinesReal = file1Real.read()
            indexC = 0
            cosine = []
            jaccard = []
            sorensen_dice = []
            qgram = []
            for rootFake, dirsFake, filesFake in os.walk(pathGemini):
                for fileFake in filesFake:
                    if fileFake.endswith(".xes") and fileFake == fileReal:
                        pathfileFake = pathGemini + fileFake
                        file2Fake = open(pathfileFake, 'r')
                        LinesFake = file2Fake.read()
                        
                        # 'Hamming-Dist': hamming_distance(LinesReal, LinesFake),
                        # 'Hamming-Sim': hamming_similarity(LinesReal, LinesFake),
                        
                        data.append({'File': fileFake, 
                                     'Levenshtein-Dist': levenshtein_distance(LinesReal, LinesFake),
                                     'Levenshtein-Sim': levenshtein_similarity(LinesReal, LinesFake),
                                     'LCS-Dist': lcs_distance(LinesReal, LinesFake),
                                     'LCS-Sim': lcs_similarity(LinesReal, LinesFake),
                                     # 'Damerau-Levenshtein-Dist': damerau_levenshtein_distance(LinesReal, LinesFake),
                                     # 'Damerau-Levenshtein-Sim': damerau_levenshtein_similarity(LinesReal, LinesFake),
                                     'Overlap': textdistance.overlap(LinesReal, LinesFake),
                                     'Jaro-Sim': jaro_similarity(LinesReal, LinesFake),
                                     # 'Jaro-winkler-Sim': jaro_winkler_similarity(LinesReal, LinesFake),
                                     '1-cosine': cosine_similarity(LinesReal, LinesFake, n=1), 
                                     '2-cosine': cosine_similarity(LinesReal, LinesFake, n=2),
                                     '3-cosine': cosine_similarity(LinesReal, LinesFake, n=3),
                                     '4-cosine': cosine_similarity(LinesReal, LinesFake, n=4),
                                     '1-jaccard': jaccard_similarity(LinesReal, LinesFake, n=1), 
                                     '2-jaccard': jaccard_similarity(LinesReal, LinesFake, n=2),
                                     '3-jaccard': jaccard_similarity(LinesReal, LinesFake, n=3),
                                     '4-jaccard': jaccard_similarity(LinesReal, LinesFake, n=4),
                                     '1-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=1), 
                                     '2-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=2),
                                     '3-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=3),
                                     '4-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=4),
                                     '1-qgram': qgram_similarity(LinesReal, LinesFake, n=1), 
                                     '2-qgram': qgram_similarity(LinesReal, LinesFake, n=2),
                                     '3-qgram': qgram_similarity(LinesReal, LinesFake, n=3),
                                     '4-qgram': qgram_similarity(LinesReal, LinesFake, n=4) })
                        print(f"Done:{fileFake}")
                   
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['File', 
                                 'Levenshtein-Dist', 'Levenshtein-Sim', 
                                 'LCS-Dist', 'LCS-Sim', 
                                 #'Damerau-Levenshtein-Dist', 'Damerau-Levenshtein-Sim', 
                                 'Overlap',
                                 'Jaro-Sim', 'Jaro-Winkler-Sim',
                                 '1-cosine', '2-cosine', '3-cosine', '4-cosine', 
                                 '1-jaccard', '2-jaccard', '3-jaccard', '4-jaccard',  
                                 '1-sorensen_dice', '2-sorensen_dice', '3-sorensen_dice', '4-sorensen_dice', 
                                 '1-qgram', '2-qgram', '3-qgram', '4-qgram'])   

df.to_excel('results_RQ1/Quality-Checker-LLAMA3-NEW.xlsx', index=False)
df.to_csv('results_RQ1/Quality-Checker-LLAMA3-NEW.csv', index=False)
# Out:
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 16.44 00%20-%20DigitalCam%20Nominal-representations.aird.xes
# Done:2024-02-13 16.44 00%20-%20DigitalCam%20Nominal-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 16.59 00%20-%20DigitalCam%20Parallel-representations.aird.xes
# Done:2024-02-13 16.59 00%20-%20DigitalCam%20Parallel-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 17.34 01%20-%20FIRFIRGCD-representations.aird.xes
# Done:2024-02-13 17.34 01%20-%20FIRFIRGCD-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 14.40 02%20-%20RT%20App-representations.aird.xes
# Done:2024-02-14 14.40 02%20-%20RT%20App-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 14.50 03%20-%20RT%20App%20Paper-representations.aird.xes
# Done:2024-02-14 14.50 03%20-%20RT%20App%20Paper-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.04 04%20-%20RT%20App%20Paper%202-representations.aird.xes
# Done:2024-02-14 15.04 04%20-%20RT%20App%20Paper%202-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.40 05%20-%20Hepsy%20Example-representations.aird.xes
# Done:2024-02-14 15.40 05%20-%20Hepsy%20Example-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.51 06%20-%20Sobel-representations.aird.xes
# Done:2024-02-14 15.51 06%20-%20Sobel-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.52 07%20-%20Roberts-representations.aird.xes
# Done:2024-02-14 15.52 07%20-%20Roberts-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 16.25 08%20-%20RASTA-PLP-representations.aird.xes
# Done:2024-02-14 16.25 08%20-%20RASTA-PLP-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.00 09%20-%20Susan-representations.aird.xes
# Done:2024-02-14 17.00 09%20-%20Susan-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.46 10%20-%20JPEG_encoder-representations.aird.xes
# Done:2024-02-14 17.46 10%20-%20JPEG_encoder-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.58 11%20-%20JPEG%20Reduced-representations.aird.xes
# Done:2024-02-14 17.58 11%20-%20JPEG%20Reduced-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 18.17 12%20-%20FIRFIRGCD_ext-representations.aird.xes
# Done:2024-02-14 18.17 12%20-%20FIRFIRGCD_ext-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 18.30 13%20-%20FIRFIRGCD_HPV-representations.aird.xes
# Done:2024-02-14 18.30 13%20-%20FIRFIRGCD_HPV-representations.aird.xes

# %%
# Correctness Metric (Syntax Check)
import os
from pytextdist.preprocessing import phrase_preprocessing
from pytextdist.edit_distance import levenshtein_distance, levenshtein_similarity
from pytextdist.vector_similarity import cosine_similarity
from pytextdist.vector_similarity import jaccard_similarity
import pandas as pd

df_syntax = pd.read_csv('Syntax.csv')

print(df_syntax)

if ((df_syntax['event'] == 'event') & (df_syntax['class'] == 'StructuredNode') & (df_syntax['featureName'] == 'ports') & (df_syntax['eventType'] == 'ADD')).any():
    print('OK')
else:
    print('NO')

pathReal = str(os.getcwd()) + '\XES-MORGAN' + '\\'
pathGemini = str(os.getcwd()) + '\XES-MORGAN-LLM-GPT4' + '\\'
print(pathReal)

for rootReal, dirsReal, filesReal in os.walk(pathGemini):
    for fileReal in filesReal:
        if fileReal.endswith(".xes"):
            pathfileReal = pathReal + fileReal
            print(pathfileReal)
            file1Real = open(pathfileReal, 'r')
            LinesReal = file1Real.readlines()
            countReal = 0
            countCorrect = 0
            # Strips the newline character
            for lineReal in LinesReal:
                countReal += 1
                str_a_beforeReal = lineReal
                str_a_afterReal = phrase_preprocessing(str_a_beforeReal, grain='word')
                # print("Line{}: {}".format(count, line.strip()))
                # print("Line{}: {}".format(countReal, str_a_afterReal))
                # print(str_a_afterReal[0]+' '+str_a_afterReal[1]+' '+str_a_afterReal[2]+' '+str_a_afterReal[3])
                if ((df_syntax['event'] == str_a_afterReal[0]) & (df_syntax['class'] == str_a_afterReal[1]) & (df_syntax['featureName'] == str_a_afterReal[2]) & (df_syntax['eventType'] == str_a_afterReal[3])).any():
                    countCorrect += 1
                else:
                    print(str_a_afterReal[0]+' '+str_a_afterReal[1]+' '+str_a_afterReal[2]+' '+str_a_afterReal[3])
            print(countCorrect)
            print(countReal)
            print('Final:'+str(countCorrect/countReal))
# Out:
#     event                  class       featureName eventType
# 0   event  behaviorspecification             nodes       add
# 1   event               stimulus              name       set
# 2   event               stimulus             ports       add
# 3   event                display              name       set
# 4   event                display             ports       add
# 5   event         structurednode             ports       add
# 6   event         structurednode         processes       add
# 7   event         structurednode         nchannels       add
# 8   event                   port         pchannels       add
# 9   event                   port     portextension       set
# 10  event                   port              name       set
# 11  event                process              name       set
# 12  event                channel             pfrom       set
# 13  event                channel               pto       set
# 14  event                channel             nfrom       set
# 15  event                channel               nto       set
# 16  event                channel              name       set
# 17  event                channel        rendezvous       set
# 18  event                channel         queuesize       set
# 19  event                channel           message       set
# 20  event                message              name       set
# 21  event                message             entry       add
# 22  event                  entry              name       set
# 23  event                  entry              type       set
# 24  event         structurednode              name       set
# 25  event         structurednode             ports    remove
# 26  event                process  processextension       set
# 27  event  behaviorspecification              name       set
# NO
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 16.44 00%20-%20DigitalCam%20Nominal-representations.aird.xes
# 104
# 104
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 16.59 00%20-%20DigitalCam%20Parallel-representations.aird.xes
# 178
# 178
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 17.34 01%20-%20FIRFIRGCD-representations.aird.xes
# 202
# 202
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 14.40 02%20-%20RT%20App-representations.aird.xes
# 74
# 74
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 14.50 03%20-%20RT%20App%20Paper-representations.aird.xes
# event channel direction set
# 88
# 89
# Final:0.9887640449438202
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.04 04%20-%20RT%20App%20Paper%202-representations.aird.xes
# 118
# 118
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.40 05%20-%20Hepsy%20Example-representations.aird.xes
# 197
# 197
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.51 06%20-%20Sobel-representations.aird.xes
# 105
# 105
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.52 07%20-%20Roberts-representations.aird.xes
# 105
# 105
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 16.25 08%20-%20RASTA-PLP-representations.aird.xes
# event channel direction set
# 129
# 130
# Final:0.9923076923076923
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.00 09%20-%20Susan-representations.aird.xes
# 81
# 81
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.46 10%20-%20JPEG_encoder-representations.aird.xes
# 289
# 289
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.58 11%20-%20JPEG%20Reduced-representations.aird.xes
# 124
# 124
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 18.17 12%20-%20FIRFIRGCD_ext-representations.aird.xes
# 332
# 332
# Final:1.0
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 18.30 13%20-%20FIRFIRGCD_HPV-representations.aird.xes
# 251
# 251
# Final:1.0

# %%
# Hallucination
import os
import re
from pytextdist.preprocessing import phrase_preprocessing
from pytextdist.edit_distance import levenshtein_distance, levenshtein_similarity
from pytextdist.vector_similarity import cosine_similarity
from pytextdist.vector_similarity import jaccard_similarity
import pandas as pd

df_syntax = pd.read_csv('Syntax.csv')

print(df_syntax)

if ((df_syntax['event'] == 'event') & (df_syntax['class'] == 'StructuredNode') & (df_syntax['featureName'] == 'ports') & (df_syntax['eventType'] == 'ADD')).any():
    print('OK')
else:
    print('NO')

pathReal = str(os.getcwd()) + '\XES-MORGAN' + '\\'
pathGemini = str(os.getcwd()) + '\XES-MORGAN-LLM-GPT4' + '\\'
pathFileNameRes = 'results_RQ1/Quality-Checker-Hallucination-GPT4.xlsx'
# 'XES-MORGAN-LLM-GEMINI', 'XES-MORGAN-LLM-GPT3.5', 'XES-MORGAN-LLM-GPT4', 'XES-MORGAN-LLM-LLAMA3'
print(pathReal)

Hall = 0;
countFiles = 0

data = []

for rootReal, dirsReal, filesReal in os.walk(pathReal):
    for fileReal in filesReal:
        countFiles += 1
        if fileReal.endswith(".xes"):
            pathfileReal = pathReal + fileReal
            print(pathfileReal)
            file1Real = open(pathfileReal, 'r')
            LinesReal = file1Real.readlines()
            countReal = 0
            # Strips the newline character
            
            # Create an empty dictionary 
            d = dict() 
            
            for lineReal in LinesReal:
                countReal += 1
                str_a_beforeReal = lineReal
                str_a_afterReal = phrase_preprocessing(str_a_beforeReal, grain='word')
                # print("Line{}: {}".format(count, line.strip()))
                # print("Line{}: {}".format(countReal, str_a_afterReal))
                
                # Remove the leading spaces and newline character 
                line = lineReal.strip() 

                # Convert the characters in line to 
                # lowercase to avoid case mismatch 
                line = line.lower() 

                # Split the line into words 
                words = line.split("  ") 
                
                # Iterate over each word in line 
                for word in words: 
                    # Check if the word is already in dictionary 
                    if word in d: 
                        # Increment count of word by 1 
                        d[word] = d[word] + 1
                    else: 
                        # Add the word to dictionary with count 1 
                        d[word] = 1
                
            # Print the contents of dictionary 
            # for key in list(d.keys()): 
            #       print(key, ":", d[key]) 
     
            # Create an empty dictionary 
            d_LLM = dict() 
            
            for rootFake, dirsFake, filesFake in os.walk(pathGemini):
                for fileFake in filesFake:
                    if fileFake.endswith(".xes") and fileFake == fileReal:
                        pathfileFake = pathGemini + fileFake
                        print(pathfileFake)
                        file2Fake = open(pathfileFake, 'r')
                        LinesFake = file2Fake.readlines()
                        countFake = 0
                        # Strips the newline character
                        for lineFake in LinesFake:
                            countFake += 1
                                    
                            # Remove the leading spaces and newline character 
                            lineF = lineFake.strip() 

                            # Convert the characters in line to 
                            # lowercase to avoid case mismatch 
                            lineF = lineF.lower() 

                            # Split the line into words 
                            wordsF = lineF.split("  ") 

                            # Iterate over each word in line 
                            for wordF in wordsF: 
                                # Check if the word is already in dictionary 
                                if wordF in d_LLM: 
                                    # Increment count of word by 1 
                                    d_LLM[wordF] = d_LLM[wordF] + 1
                                else: 
                                    # Add the word to dictionary with count 1 
                                    d_LLM[wordF] = 1

            # Print the contents of dictionary 
            valueReal = 0
            valueLLM = 0
            countMax = 0
            for key in list(d_LLM.keys()): 
                # print(key, ":", d_LLM[key]) 
                res = [val for keyR, val in d.items() if key == keyR]
                if not res:
                    valueX = 1
                    # print('No Res')
                else:
                    # print(res)
                    valueReal += d[key]
                    valueLLM += d_LLM[key]
                    if countMax < d_LLM[key]/d[key]:
                        countMax = d_LLM[key]/d[key]
                        # print('CountMax Partial: ' + str(countMax))
                        keyMax = key
                        # print('keyMax Partial: ' + str(keyMax))
                    if (d[key]!= 0):
                        print('Key: ' + key + ' H: ' + str(d_LLM[key]/d[key]))
                        data.append({'File': (pathfileReal.split('\\')[-1]), 'Key': key,'Hallucination': (d_LLM[key]/d[key])})

            if (valueReal!= 0):
                print('Final Hallucination for: ' + (pathfileReal.split('\\')[-1]) + ', value: ' + str(valueLLM/valueReal))
                print('Max: ' + str(countMax) + ' for ' + str(keyMax))
                Hall += (valueLLM/valueReal)
            d.clear()
            d_LLM.clear()

print('Final: ' + str(Hall/countFiles))

# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['File','Key','Hallucination'])   

df.to_excel(pathFileNameRes, index=False)
# Out:
#     event                  class       featureName eventType
# 0   event  behaviorspecification             nodes       add
# 1   event               stimulus              name       set
# 2   event               stimulus             ports       add
# 3   event                display              name       set
# 4   event                display             ports       add
# 5   event         structurednode             ports       add
# 6   event         structurednode         processes       add
# 7   event         structurednode         nchannels       add
# 8   event                   port         pchannels       add
# 9   event                   port     portextension       set
# 10  event                   port              name       set
# 11  event                process              name       set
# 12  event                channel             pfrom       set
# 13  event                channel               pto       set
# 14  event                channel             nfrom       set
# 15  event                channel               nto       set
# 16  event                channel              name       set
# 17  event                channel        rendezvous       set
# 18  event                channel         queuesize       set
# 19  event                channel           message       set
# 20  event                message              name       set
# 21  event                message             entry       add
# 22  event                  entry              name       set
# 23  event                  entry              type       set
# 24  event         structurednode              name       set
# 25  event         structurednode             ports    remove
# 26  event                process  processextension       set
# 27  event  behaviorspecification              name       set
# NO
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 16.44 00%20-%20DigitalCam%20Nominal-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-13 16.44 00%20-%20DigitalCam%20Nominal-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 0.5
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.8333333333333334
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 0.5
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 0.7142857142857143
# Key: event channel message set H: 1.0
# Key: event message name set H: 1.0
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 0.625
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode name set H: 0.5
# Key: event structurednode ports add H: 0.6666666666666666
# Key: event port portextension set H: 0.5
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 0.6666666666666666
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Final Hallucination for: 2024-02-13 16.44 00%20-%20DigitalCam%20Nominal-representations.aird.xes, value: 0.8415841584158416
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 16.59 00%20-%20DigitalCam%20Parallel-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-13 16.59 00%20-%20DigitalCam%20Parallel-representations.aird.xes
# Key: event channel name set H: 0.13333333333333333
# Key: event channel queuesize set H: 0.14285714285714285
# Key: event channel rendezvous set H: 0.125
# Key: event channel message set H: 0.14285714285714285
# Key: event message name set H: 0.14285714285714285
# Key: event message entry add H: 0.14285714285714285
# Key: event entry name set H: 0.13333333333333333
# Key: event entry type set H: 0.10526315789473684
# Key: event structurednode processes add H: 1.7142857142857142
# Key: event process name set H: 1.5
# Key: event channel nfrom set H: 0.07142857142857142
# Key: event channel nto set H: 0.07142857142857142
# Final Hallucination for: 2024-02-13 16.59 00%20-%20DigitalCam%20Parallel-representations.aird.xes, value: 0.25609756097560976
# Max: 1.7142857142857142 for event structurednode processes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-13 17.34 01%20-%20FIRFIRGCD-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-13 17.34 01%20-%20FIRFIRGCD-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 0.5
# Key: event port name set H: 0.8333333333333334
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.35714285714285715
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event channel queuesize set H: 0.6153846153846154
# Key: event channel rendezvous set H: 0.6153846153846154
# Key: event channel message set H: 0.6666666666666666
# Key: event message name set H: 0.6666666666666666
# Key: event message entry add H: 0.6666666666666666
# Key: event entry name set H: 0.6153846153846154
# Key: event entry type set H: 0.4444444444444444
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 0.6666666666666666
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 0.5833333333333334
# Key: event channel nfrom set H: 0.5833333333333334
# Key: event channel nto set H: 0.5833333333333334
# Key: event structurednode processes add H: 0.875
# Key: event process name set H: 0.875
# Key: event process processextension set H: 4.0
# Final Hallucination for: 2024-02-13 17.34 01%20-%20FIRFIRGCD-representations.aird.xes, value: 0.6435643564356436
# Max: 4.0 for event process processextension set
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 14.40 02%20-%20RT%20App-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 14.40 02%20-%20RT%20App-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.8333333333333334
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode name set H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 1.0
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 0.6
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 0.8
# Key: event process processextension set H: 0.3333333333333333
# Final Hallucination for: 2024-02-14 14.40 02%20-%20RT%20App-representations.aird.xes, value: 0.918918918918919
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 14.50 03%20-%20RT%20App%20Paper-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 14.50 03%20-%20RT%20App%20Paper-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 0.8
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.8571428571428571
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 0.8
# Key: event channel nfrom set H: 0.8
# Key: event channel nto set H: 0.8
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 0.8
# Key: event channel direction set H: 4.0
# Key: event channel message set H: 0.8
# Key: event message name set H: 0.8
# Key: event message entry add H: 0.8
# Key: event entry name set H: 0.8
# Key: event entry type set H: 0.5714285714285714
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 1.0
# Final Hallucination for: 2024-02-14 14.50 03%20-%20RT%20App%20Paper-representations.aird.xes, value: 0.8876404494382022
# Max: 4.0 for event channel direction set
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.04 04%20-%20RT%20App%20Paper%202-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 15.04 04%20-%20RT%20App%20Paper%202-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.9090909090909091
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 1.0
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 1.0
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 1.5
# Final Hallucination for: 2024-02-14 15.04 04%20-%20RT%20App%20Paper%202-representations.aird.xes, value: 1.0
# Max: 1.5 for event process processextension set
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.40 05%20-%20Hepsy%20Example-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 15.40 05%20-%20Hepsy%20Example-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.9411764705882353
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 0.9090909090909091
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 0.9090909090909091
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 1.0
# Final Hallucination for: 2024-02-14 15.40 05%20-%20Hepsy%20Example-representations.aird.xes, value: 0.9847715736040609
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.51 06%20-%20Sobel-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 15.51 06%20-%20Sobel-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 0.8
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.8888888888888888
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 0.8571428571428571
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 0.6666666666666666
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 1.0
# Final Hallucination for: 2024-02-14 15.51 06%20-%20Sobel-representations.aird.xes, value: 0.9428571428571428
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 15.52 07%20-%20Roberts-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 15.52 07%20-%20Roberts-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 16.25 08%20-%20RASTA-PLP-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 16.25 08%20-%20RASTA-PLP-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 1.0
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 0.8888888888888888
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 0.7272727272727273
# Key: event channel direction set H: 1.0
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 1.0
# Final Hallucination for: 2024-02-14 16.25 08%20-%20RASTA-PLP-representations.aird.xes, value: 0.9692307692307692
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.00 09%20-%20Susan-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 17.00 09%20-%20Susan-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 1.0
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 0.3333333333333333
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 1.0
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 1.0
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 0.3333333333333333
# Final Hallucination for: 2024-02-14 17.00 09%20-%20Susan-representations.aird.xes, value: 0.9506172839506173
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.46 10%20-%20JPEG_encoder-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 17.46 10%20-%20JPEG_encoder-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.13636363636363635
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 0.05
# Key: event channel nfrom set H: 0.05
# Key: event channel nto set H: 0.05
# Key: event channel queuesize set H: 0.05555555555555555
# Key: event channel rendezvous set H: 0.05
# Key: event channel message set H: 0.05
# Key: event message name set H: 0.043478260869565216
# Key: event message entry add H: 0.05263157894736842
# Key: event entry name set H: 0.05263157894736842
# Key: event entry type set H: 0.027777777777777776
# Key: event structurednode processes add H: 0.3125
# Key: event process name set H: 0.4117647058823529
# Key: event process processextension set H: 1.0
# Final Hallucination for: 2024-02-14 17.46 10%20-%20JPEG_encoder-representations.aird.xes, value: 0.1522491349480969
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 17.58 11%20-%20JPEG%20Reduced-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 17.58 11%20-%20JPEG%20Reduced-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 0.8
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 1.0
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 1.0
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 1.0
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Key: event process processextension set H: 1.0
# Final Hallucination for: 2024-02-14 17.58 11%20-%20JPEG%20Reduced-representations.aird.xes, value: 0.9919354838709677
# Max: 1.0 for event behaviorspecification nodes add
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 18.17 12%20-%20FIRFIRGCD_ext-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 18.17 12%20-%20FIRFIRGCD_ext-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 0.9310344827586207
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0434782608695652
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 1.0
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 0.8
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 0.9333333333333333
# Final Hallucination for: 2024-02-14 18.17 12%20-%20FIRFIRGCD_ext-representations.aird.xes, value: 0.9758308157099698
# Max: 1.0434782608695652 for event channel queuesize set
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN\2024-02-14 18.30 13%20-%20FIRFIRGCD_HPV-representations.aird.xes
# C:\Users\vitto\Desktop\github\modelingOperationRec_ASE\Quality_Checker\XES-MORGAN-LLM-GPT4\2024-02-14 18.30 13%20-%20FIRFIRGCD_HPV-representations.aird.xes
# Key: event behaviorspecification nodes add H: 1.0
# Key: event stimulus name set H: 1.0
# Key: event stimulus ports add H: 1.0
# Key: event port name set H: 1.0
# Key: event port pchannels add H: 1.0
# Key: event channel name set H: 1.0
# Key: event channel pfrom set H: 1.0
# Key: event channel pto set H: 1.0
# Key: event display name set H: 1.0
# Key: event display ports add H: 1.0
# Key: event structurednode ports add H: 1.0
# Key: event port portextension set H: 1.0
# Key: event structurednode nchannels add H: 1.0
# Key: event channel nfrom set H: 1.0
# Key: event channel nto set H: 1.0
# Key: event channel queuesize set H: 1.0
# Key: event channel rendezvous set H: 1.0
# Key: event channel message set H: 1.0
# Key: event message name set H: 1.0
# Key: event message entry add H: 1.0
# Key: event entry name set H: 1.0
# Key: event entry type set H: 0.7391304347826086
# Key: event structurednode processes add H: 1.0
# Key: event process name set H: 1.0
# Final Hallucination for: 2024-02-14 18.30 13%20-%20FIRFIRGCD_HPV-representations.aird.xes, value: 0.976
# Max: 1.0 for event behaviorspecification nodes add
# Final: 0.7660865098903893
